# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
baseurl = 'https://www.ryanscomputers.com/'

# %%
baseurllaptop ='https://www.ryanscomputers.com/category/laptop-all-laptop'
headers= {
    'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
productlist = soup.find_all('div', class_="product-content-info")

# %%
print(productlist)
print(len(productlist))
# Out:
# [<div class="product-content-info" data-nosnippet="">
# <p class="product-head" data-nosnippet="" style="display:none;">Core i5 Laptop</p>
# <a class="product-title-grid" href="https://www.ryanscomputers.com/avita-liber-intel-core-i5-8250u-133-inch-fhd-ips-display-matt-black-laptop">Avita LIBER Intel Core i5 8250U 13.3 Inch FHD IPS ...</a>
# <div class="stars">
# <span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span>
# </div>
# <a href="https://www.ryanscomputers.com/avita-liber-intel-core-i5-8250u-133-inch-fhd-ips-display-matt-black-laptop">33.01.780.10</a>
# <div class="price-label" data-nosnippet="">
# <div class="regular-price-grid" data-nosnippet="">
#                                                         Price <span class="old-price">                                                             60,980</span>
# </div>
# ...

# %%
for item in productlist:
    game= item.text.strip()
    print(game)

# %%
productnamec=[]
productlink = []
for x in range(1,19):
    r = requests.get(f'https://www.ryanscomputers.com/category/laptop-all-laptop?page={x}&limit=18&query=')
    soup = BeautifulSoup(r.content,'lxml')
    for item in productlist:
        for link in item.find_all('a',href=True):
            productlink.append(link['href'])
    
del productlink[1::2]
print(productlink) 
print(len(productlink))
# Out:
# ['https://www.ryanscomputers.com/avita-liber-intel-core-i5-8250u-133-inch-fhd-ips-display-matt-black-laptop', 'https://www.ryanscomputers.com/dell-g7-15-7591-intel-core-i5-9300h-156-inch-fhd-display-silver-gaming-laptop', 'https://www.ryanscomputers.com/acer-extensa-15-ex215-52-384m-intel-core-i3-1005g1-156-inch-fhd-display-black-laptop', 'https://www.ryanscomputers.com/dell-vostro-14-3400-intel-core-i3-1115g4-14-inch-hd-display-black-laptop', 'https://www.ryanscomputers.com/dell-latitude-14-5410-intel-core-i5-10210u-14-inch-fhd-display-grey-laptop', 'https://www.ryanscomputers.com/avita-magus-intel-cdc-n3350-12.2-inch-fhd+-ips-touch-display-pastel-violet-laptop', 'https://www.ryanscomputers.com/avita-magus-intel-cdc-n3350-12.2-inch-fhd+-ips-touch-display-charcoal-grey-laptop', 'https://www.ryanscomputers.com/avita-magus-intel-cdc-n3350-64gb-emmc-+-64gb-mmc-12.2-inch-fhd+-ips-touch-display-steel-blue-laptop', 'https://www.ryanscomputers.com/avita-magus-intel-cdc-n3350-64gb-emmc-+-64g
# ...

# %%
for x in range(1,6):
    print(x)
# Out:
# 1
# 2
# 3
# 4
# 5
