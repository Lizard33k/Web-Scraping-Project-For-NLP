# %%
import requests
import pandas as pd

# %%
from bs4 import BeautifulSoup

# %%
baseurl = 'https://www.ryanscomputers.com/'

# %%
baseurllaptop ='https://www.ryanscomputers.com/category/laptop-all-laptop'
headers= {
    'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36'
}

# %%
pip install lxml
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\User\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
productlist = soup.find_all('div', class_="product-content-info")

# %%
print(productlist)
print(len(productlist))
# Out:
# [<div class="product-content-info" data-nosnippet="">
# <p class="product-head" data-nosnippet="" style="display:none;">Core i5 Laptop</p>
# <a class="product-title-grid" href="https://www.ryanscomputers.com/avita-liber-intel-core-i5-8250u-133-inch-fhd-ips-display-matt-black-laptop">Avita LIBER Intel Core i5 8250U 13.3 Inch FHD IPS ...</a>
# <div class="stars">
# <span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span><span class="fa fa-star"></span>
# </div>
# <a href="https://www.ryanscomputers.com/avita-liber-intel-core-i5-8250u-133-inch-fhd-ips-display-matt-black-laptop">33.01.780.10</a>
# <div class="price-label" data-nosnippet="">
# <div class="regular-price-grid" data-nosnippet="">
#                                                         Price <span class="old-price">                                                             60,980</span>
# </div>
# ...

# %%
productnamec=[]
productlink = []
for x in range(1,19):
   
    r = requests.get(f'https://www.ryanscomputers.com/category/laptop-all-laptop?page={x}&limit=18&query=',headers=headers)
    soup = BeautifulSoup(r.content,'lxml')
    productlist = soup.find_all('div', class_="product-content-info")
    for item in productlist:
        for link in item.find_all('a',href=True):
            productlink.append(link['href'])
    
del productlink[1::2]
print(productlink) 
print(len(productlink))

# %%
print(productlink)

# %%
testlink = 'https://www.ryanscomputers.com/avita-magus-intel-cdc-n3350-64gb-emmc-+-64gb-mmc-12.2-inch-fhd+-ips-touch-display-steel-blue-laptop'
z= requests.get(testlink,headers=headers)
soup = BeautifulSoup(z.content,'lxml')

# %%
name = soup.find('h1',class_='product-title product-title-style').text.strip()

# %%
print(name)
# Out:
# Avita Magus Intel CDC N3350 64GB eMMC + 64GB MMC 12.2 Inch FHD+ IPS Touch Display Steel Blue Laptop #NS12T5BD005P

# %%
rating = soup.find_all('span',class_='fa fa-star')
ratings = len(rating)/2
print(ratings)
# Out:
# 3.0

# %%
price = soup.find('span',class_='price').text.strip()
print(price)
# Out:
# 24,750

# %%
number_of_reviews=  soup.find('a',class_='customers-rating').text.strip()
print(number_of_reviews)
# Out:
# 1
#                                     reviews

# %%
Laptop = {
    'name': name,
    'rating': ratings,
    'price' : price,
    'Total Reviews' : number_of_reviews
}
print(Laptop)
# Out:
# {'name': 'Avita Magus Intel CDC N3350 64GB eMMC + 64GB MMC 12.2 Inch FHD+ IPS Touch Display Steel Blue Laptop #NS12T5BD005P', 'rating': 3.0, 'price': '24,750', 'Total Reviews': '1\n                                    reviews'}

# %%
laptoplist =[]
for link in productlink:

    z= requests.get(link,headers=headers)
    soup = BeautifulSoup(z.content,'lxml')
    name = soup.find('h1',class_='product-title product-title-style').text.strip()
    rating = soup.find_all('span',class_='fa fa-star')
    ratings = len(rating)/2
    price = soup.find('span',class_='price').text.strip()
    try:
        number_of_reviews=  soup.find('a',class_='customers-rating').text.strip()
    except:
        number_of_reviews = 0
    Laptop = {
        'name': name,
        'rating': ratings,
        'price' : price,
        'Total Reviews' : number_of_reviews
}
    laptoplist.append(Laptop)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17832/2508512124.py in <module>
#       2 for link in productlink:
#       3
# ----> 4     z= requests.get(link,headers=headers)
#       5     soup = BeautifulSoup(z.content,'lxml')
#       6     name = soup.find('h1',class_='product-title product-title-style').text.strip()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
# ...

# %%
df=pd.DataFrame(laptoplist)
df
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...    10.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...     5.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...    12.5  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...    15.0  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...     7.5  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...     5.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...     5.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...     7.5  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...     5.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...     7.5  37,000
#
#                                        Total Reviews
# 0     3\n                                    reviews
# ...

# %%
df.to_csv('Ryans COmputer Laptop2.csv')

# %%
df['rating'] = 2* df['rating']

# %%
df
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...    20.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...    10.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...    25.0  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...    30.0  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...    15.0  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...    10.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...    10.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    15.0  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    10.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...    15.0  37,000
#
#                                        Total Reviews
# 0     3\n                                    reviews
# ...

# %%
df = df.replace(r'\n',' ', regex=True)

# %%
df
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...    20.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...    10.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...    25.0  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...    30.0  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...    15.0  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...    10.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...    10.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    15.0  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    10.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...    15.0  37,000
#
#                                       Total Reviews
# 0     3                                     reviews
# ...

# %%
df['Total Reviews'] = df['Total Reviews'].str.replace('reviews','')

# %%
df
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...    20.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...    10.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...    25.0  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...    30.0  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...    15.0  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...    10.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...    10.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    15.0  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    10.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...    15.0  37,000
#
#                                Total Reviews
# 0     3
# 1     1
# 2     4
# 3    11
# 4     2
# ...

# %%
df['Total Reviews'] = pd.to_numeric(df['Total Reviews'])

# %%
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...    20.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...    10.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...    25.0  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...    30.0  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...    15.0  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...    10.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...    10.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    15.0  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...    10.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...    15.0  37,000
#
#      Total Reviews
# 0              3.0
# 1              1.0
# 2              4.0
# 3             11.0
# ...

# %%
df['rating'] =  df['rating']/(df['Total Reviews']+1)

# %%
df
# Out:
#                                                   name  rating   price  \
# 0    Avita LIBER Intel Core i5 8250U 13.3 Inch FHD ...     5.0  56,700
# 1    Dell G7 15-7591 Intel Core i5 9300H 15.6 Inch ...     5.0  85,000
# 2    Acer Extensa 15 EX215-52-384M Intel Core i3 10...     5.0  44,000
# 3    Dell Vostro 14 3400 Intel Core i3 1115G4 14 In...     2.5  46,800
# 4    Dell Latitude 14-5410 Intel Core i5 10210U 14 ...     5.0  81,000
# ..                                                 ...     ...     ...
# 319  Acer Extensa 15 EX215-22-A789 AMD Athlon 3020E...     5.0  35,500
# 320  Acer Aspire 3 A315-23 AMD Athlon Silver 3050U ...     5.0  36,000
# 321  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...     5.0  36,500
# 322  Dell Inspiron 15-3505 AMD Athlon Silver 3050U ...     5.0  36,500
# 323  HP 15s-gr515AU AMD Athlon Silver 3050U 15.6 In...     5.0  37,000
#
#      Total Reviews
# 0              3.0
# 1              1.0
# 2              4.0
# 3             11.0
# ...

# %%
df.to_csv('Ryans COmputer Laptop3.csv')
